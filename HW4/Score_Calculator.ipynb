# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/CPSC-8430-Deep-Learning-001/HW4/'

# %%
DCGAN = np.load(path+'Results/FID_score/DC_FID.npy')
WGANGP = np.load(path+'Results/FID_score/WGANGP_FID.npy')
ACGAN = np.load(path+'Results/FID_score/ACGAN_FID.npy')

# %%
plt.figure(figsize=(10,5))
plt.title("FID Scores comparsions for DCGAN vs WGAN vs ACGAN")
plt.plot(DCGAN,label="DCGAN",color='red')
plt.plot(WGANGP,label="WGAN",color='green')
plt.plot(ACGAN,label="ACGAN")
plt.xlabel("Epochs")
plt.ylabel("FID")
plt.legend()
plt.savefig(path+'Results/FID_summary.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
plt.show()

# %%
np.min(WGANGP),np.mean(WGANGP), WGANGP[39]
# Out:
# (277.75164465229284, 312.20539475734523, 299.1962095515197)
