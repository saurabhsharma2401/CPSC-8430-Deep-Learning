# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
torch.manual_seed(1)

# %%
def load_data(train_batch_size, test_batch_size):
    # Fetch training data: total 60000 samples

    trainset = datasets.MNIST('data', train = True, download = True,
                transform = transforms.Compose([
                transforms.Resize((32,32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    temp = torch.tensor(np.random.randint(0, 10, (len(trainset)),))
    trainset.targets = temp
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

    testset = datasets.MNIST('data', train = True,
                transform = transforms.Compose([
                transforms.Resize((32, 32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    test_loader = torch.utils.data.DataLoader(testset ,batch_size = test_batch_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        return x

# %%
train_batch_size = 100
test_batch_size = 100
train_loader, test_loader = load_data(train_batch_size, test_batch_size)
# Out:
# 3.0%
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data\MNIST\raw\train-images-idx3-ubyte.gz
# 100.0%
# Extracting data\MNIST\raw\train-images-idx3-ubyte.gz to data\MNIST\raw
# 100.0%
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data\MNIST\raw\train-labels-idx1-ubyte.gz
# Extracting data\MNIST\raw\train-labels-idx1-ubyte.gz to data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data\MNIST\raw\t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting data\MNIST\raw\t10k-images-idx3-ubyte.gz to data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data\MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100.0%
# Extracting data\MNIST\raw\t10k-labels-idx1-ubyte.gz to data\MNIST\raw

# %%
def train(model, optimizer, train_loader):
    model.train()
    correct = 0
    train_loss = 0
    counter = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        counter += 1
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.data

        pred = np.argmax(output.data, axis=1)
        correct += np.equal(pred, target.data).sum()

    train_loss = (train_loss * 100) / len(train_loader.dataset)
    acc = 100.0 * correct / len(train_loader.dataset)
    return train_loss, acc

# %%
def test(model, epoch, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    for data, target in test_loader:
        data, target = Variable(data), Variable(target)

        output = model(data)
        loss = loss_fn(output, target)
        test_loss += loss.data

        pred = np.argmax(output.data, axis = 1)
        correct = correct + np.equal(pred, target.data).sum()

    # Print log
    test_loss = (test_loss * 100) / len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch,
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss

# %%
model = CNN()

optimizer = optim.Adam(model.parameters(), lr=0.0001)
m1_train_loss_arr = []
m1_test_loss_arr = []

epochs = 100
log_interval = 500
loss_fn = torch.nn.CrossEntropyLoss()
for epoch in range(1, epochs + 1):
    tr_loss, acc = train(model, optimizer, train_loader)
    m1_train_loss_arr.append(tr_loss)
    loss_test = test(model, epoch, test_loader)
    m1_test_loss_arr.append(loss_test)
    print('Epoch: ', epoch)
    print('Loss= ', tr_loss)
# Out:
# Test set, Epoch 1 , Average loss: 2.3026, Accuracy: 5381/60000 (9%)
#
# Epoch:  1
# Loss=  tensor(2.3032)
#
# Test set, Epoch 2 , Average loss: 2.3005, Accuracy: 6845/60000 (11%)
#
# Epoch:  2
# Loss=  tensor(2.3023)
#
# Test set, Epoch 3 , Average loss: 2.3006, Accuracy: 4731/60000 (8%)
#
# Epoch:  3
# Loss=  tensor(2.3018)
#
# Test set, Epoch 4 , Average loss: 2.3026, Accuracy: 4079/60000 (7%)
#
# Epoch:  4
# Loss=  tensor(2.3012)
#
# Test set, Epoch 5 , Average loss: 2.2989, Accuracy: 4795/60000 (8%)
#
# Epoch:  5
# Loss=  tensor(2.3005)
#
# Test set, Epoch 6 , Average loss: 2.3022, Accuracy: 4790/60000 (8%)
#
# Epoch:  6
# Loss=  tensor(2.2995)
#
# Test set, Epoch 7 , Average loss: 2.2940, Accuracy: 5249/60000 (9%)
#
# Epoch:  7
# Loss=  tensor(2.2985)
#
# Test set, Epoch 8 , Average loss: 2.2966, Accuracy: 6974/60000 (12%)
#
# Epoch:  8
# Loss=  tensor(2.2972)
#
# Test set, Epoch 9 , Average loss: 2.3006, Accuracy: 5251/60000 (9%)
#
# Epoch:  9
# Loss=  tensor(2.2960)
#
# Test set, Epoch 10 , Average loss: 2.3092, Accuracy: 4300/60000 (7%)
#
# Epoch:  10
# Loss=  tensor(2.2943)
#
# Test set, Epoch 11 , Average loss: 2.3053, Accuracy: 5805/60000 (10%)
#
# Epoch:  11
# Loss=  tensor(2.2926)
#
# Test set, Epoch 12 , Average loss: 2.2949, Accuracy: 7124/60000 (12%)
#
# Epoch:  12
# Loss=  tensor(2.2907)
#
# Test set, Epoch 13 , Average loss: 2.2928, Accuracy: 6544/60000 (11%)
#
# Epoch:  13
# Loss=  tensor(2.2885)
#
# Test set, Epoch 14 , Average loss: 2.2912, Accuracy: 7694/60000 (13%)
#
# Epoch:  14
# Loss=  tensor(2.2863)
#
# Test set, Epoch 15 , Average loss: 2.3007, Accuracy: 7571/60000 (13%)
#
# Epoch:  15
# Loss=  tensor(2.2837)
#
# Test set, Epoch 16 , Average loss: 2.3097, Accuracy: 5715/60000 (10%)
#
# Epoch:  16
# Loss=  tensor(2.2811)
#
# Test set, Epoch 17 , Average loss: 2.3190, Accuracy: 5853/60000 (10%)
#
# Epoch:  17
# Loss=  tensor(2.2785)
#
# Test set, Epoch 18 , Average loss: 2.3079, Accuracy: 6478/60000 (11%)
#
# Epoch:  18
# Loss=  tensor(2.2756)
#
# Test set, Epoch 19 , Average loss: 2.3038, Accuracy: 7382/60000 (12%)
#
# Epoch:  19
# Loss=  tensor(2.2727)
#
# Test set, Epoch 20 , Average loss: 2.3273, Accuracy: 5911/60000 (10%)
#
# Epoch:  20
# Loss=  tensor(2.2695)
#
# Test set, Epoch 21 , Average loss: 2.3043, Accuracy: 6911/60000 (12%)
#
# Epoch:  21
# Loss=  tensor(2.2661)
#
# Test set, Epoch 22 , Average loss: 2.3156, Accuracy: 7048/60000 (12%)
#
# Epoch:  22
# Loss=  tensor(2.2629)
#
# Test set, Epoch 23 , Average loss: 2.3175, Accuracy: 6697/60000 (11%)
#
# Epoch:  23
# Loss=  tensor(2.2593)
#
# Test set, Epoch 24 , Average loss: 2.3160, Accuracy: 7028/60000 (12%)
#
# Epoch:  24
# Loss=  tensor(2.2555)
#
# Test set, Epoch 25 , Average loss: 2.3053, Accuracy: 7304/60000 (12%)
#
# Epoch:  25
# Loss=  tensor(2.2522)
#
# Test set, Epoch 26 , Average loss: 2.3294, Accuracy: 5999/60000 (10%)
#
# Epoch:  26
# Loss=  tensor(2.2485)
#
# Test set, Epoch 27 , Average loss: 2.3199, Accuracy: 7411/60000 (12%)
#
# Epoch:  27
# Loss=  tensor(2.2456)
#
# Test set, Epoch 28 , Average loss: 2.3277, Accuracy: 6714/60000 (11%)
#
# Epoch:  28
# Loss=  tensor(2.2416)
#
# Test set, Epoch 29 , Average loss: 2.3248, Accuracy: 7201/60000 (12%)
#
# Epoch:  29
# Loss=  tensor(2.2375)
#
# Test set, Epoch 30 , Average loss: 2.3261, Accuracy: 6573/60000 (11%)
#
# Epoch:  30
# Loss=  tensor(2.2339)
#
# Test set, Epoch 31 , Average loss: 2.3549, Accuracy: 6204/60000 (10%)
#
# Epoch:  31
# Loss=  tensor(2.2305)
#
# Test set, Epoch 32 , Average loss: 2.3575, Accuracy: 5990/60000 (10%)
#
# Epoch:  32
# Loss=  tensor(2.2270)
#
# Test set, Epoch 33 , Average loss: 2.3274, Accuracy: 7170/60000 (12%)
#
# Epoch:  33
# Loss=  tensor(2.2228)
#
# Test set, Epoch 34 , Average loss: 2.3712, Accuracy: 5383/60000 (9%)
#
# Epoch:  34
# Loss=  tensor(2.2194)
#
# Test set, Epoch 35 , Average loss: 2.3532, Accuracy: 6681/60000 (11%)
#
# Epoch:  35
# Loss=  tensor(2.2155)
#
# Test set, Epoch 36 , Average loss: 2.3554, Accuracy: 6312/60000 (11%)
#
# Epoch:  36
# Loss=  tensor(2.2118)
#
# Test set, Epoch 37 , Average loss: 2.3618, Accuracy: 6226/60000 (10%)
#
# Epoch:  37
# Loss=  tensor(2.2079)
#
# Test set, Epoch 38 , Average loss: 2.3562, Accuracy: 6568/60000 (11%)
#
# Epoch:  38
# Loss=  tensor(2.2041)
#
# Test set, Epoch 39 , Average loss: 2.3807, Accuracy: 6456/60000 (11%)
#
# Epoch:  39
# Loss=  tensor(2.1998)
#
# Test set, Epoch 40 , Average loss: 2.3652, Accuracy: 6454/60000 (11%)
#
# Epoch:  40
# Loss=  tensor(2.1960)
#
# Test set, Epoch 41 , Average loss: 2.3942, Accuracy: 6113/60000 (10%)
#
# Epoch:  41
# Loss=  tensor(2.1921)
#
# Test set, Epoch 42 , Average loss: 2.3552, Accuracy: 6683/60000 (11%)
#
# Epoch:  42
# Loss=  tensor(2.1885)
#
# Test set, Epoch 43 , Average loss: 2.3860, Accuracy: 6164/60000 (10%)
#
# Epoch:  43
# Loss=  tensor(2.1846)
#
# Test set, Epoch 44 , Average loss: 2.4090, Accuracy: 5989/60000 (10%)
#
# Epoch:  44
# Loss=  tensor(2.1808)
#
# Test set, Epoch 45 , Average loss: 2.4093, Accuracy: 5738/60000 (10%)
#
# Epoch:  45
# Loss=  tensor(2.1772)
#
# Test set, Epoch 46 , Average loss: 2.3947, Accuracy: 6476/60000 (11%)
#
# Epoch:  46
# Loss=  tensor(2.1725)
#
# Test set, Epoch 47 , Average loss: 2.3763, Accuracy: 6550/60000 (11%)
#
# Epoch:  47
# Loss=  tensor(2.1694)
#
# Test set, Epoch 48 , Average loss: 2.3912, Accuracy: 6577/60000 (11%)
#
# Epoch:  48
# Loss=  tensor(2.1656)
#
# Test set, Epoch 49 , Average loss: 2.3980, Accuracy: 6327/60000 (11%)
#
# Epoch:  49
# Loss=  tensor(2.1612)
#
# Test set, Epoch 50 , Average loss: 2.4386, Accuracy: 6104/60000 (10%)
#
# Epoch:  50
# Loss=  tensor(2.1582)
#
# Test set, Epoch 51 , Average loss: 2.4166, Accuracy: 6096/60000 (10%)
#
# Epoch:  51
# Loss=  tensor(2.1544)
#
# Test set, Epoch 52 , Average loss: 2.4454, Accuracy: 5898/60000 (10%)
#
# Epoch:  52
# Loss=  tensor(2.1493)
#
# Test set, Epoch 53 , Average loss: 2.4236, Accuracy: 5953/60000 (10%)
#
# Epoch:  53
# Loss=  tensor(2.1460)
#
# Test set, Epoch 54 , Average loss: 2.4261, Accuracy: 6129/60000 (10%)
#
# Epoch:  54
# Loss=  tensor(2.1426)
#
# Test set, Epoch 55 , Average loss: 2.4723, Accuracy: 5524/60000 (9%)
#
# Epoch:  55
# Loss=  tensor(2.1380)
#
# Test set, Epoch 56 , Average loss: 2.4199, Accuracy: 6363/60000 (11%)
#
# Epoch:  56
# Loss=  tensor(2.1340)
#
# Test set, Epoch 57 , Average loss: 2.4283, Accuracy: 6218/60000 (10%)
#
# Epoch:  57
# Loss=  tensor(2.1311)
#
# Test set, Epoch 58 , Average loss: 2.4596, Accuracy: 5738/60000 (10%)
#
# Epoch:  58
# Loss=  tensor(2.1274)
#
# Test set, Epoch 59 , Average loss: 2.4862, Accuracy: 5390/60000 (9%)
#
# Epoch:  59
# Loss=  tensor(2.1234)
#
# Test set, Epoch 60 , Average loss: 2.4217, Accuracy: 6824/60000 (11%)
#
# Epoch:  60
# Loss=  tensor(2.1198)
#
# Test set, Epoch 61 , Average loss: 2.4703, Accuracy: 6005/60000 (10%)
#
# Epoch:  61
# Loss=  tensor(2.1151)
#
# Test set, Epoch 62 , Average loss: 2.4124, Accuracy: 7481/60000 (12%)
#
# Epoch:  62
# Loss=  tensor(2.1120)
#
# Test set, Epoch 63 , Average loss: 2.4851, Accuracy: 5710/60000 (10%)
#
# Epoch:  63
# Loss=  tensor(2.1093)
#
# Test set, Epoch 64 , Average loss: 2.4433, Accuracy: 6837/60000 (11%)
#
# Epoch:  64
# Loss=  tensor(2.1045)
#
# Test set, Epoch 65 , Average loss: 2.4845, Accuracy: 5644/60000 (9%)
#
# Epoch:  65
# Loss=  tensor(2.1011)
#
# Test set, Epoch 66 , Average loss: 2.4484, Accuracy: 6585/60000 (11%)
#
# Epoch:  66
# Loss=  tensor(2.0976)
#
# Test set, Epoch 67 , Average loss: 2.5039, Accuracy: 5747/60000 (10%)
#
# Epoch:  67
# Loss=  tensor(2.0933)
#
# Test set, Epoch 68 , Average loss: 2.4886, Accuracy: 5836/60000 (10%)
#
# Epoch:  68
# Loss=  tensor(2.0890)
#
# Test set, Epoch 69 , Average loss: 2.4988, Accuracy: 5781/60000 (10%)
#
# Epoch:  69
# Loss=  tensor(2.0862)
#
# Test set, Epoch 70 , Average loss: 2.4893, Accuracy: 6253/60000 (10%)
#
# Epoch:  70
# Loss=  tensor(2.0817)
#
# Test set, Epoch 71 , Average loss: 2.5315, Accuracy: 5762/60000 (10%)
#
# Epoch:  71
# Loss=  tensor(2.0794)
#
# Test set, Epoch 72 , Average loss: 2.4604, Accuracy: 6540/60000 (11%)
#
# Epoch:  72
# Loss=  tensor(2.0750)
#
# Test set, Epoch 73 , Average loss: 2.4893, Accuracy: 6396/60000 (11%)
#
# Epoch:  73
# Loss=  tensor(2.0713)
#
# Test set, Epoch 74 , Average loss: 2.5438, Accuracy: 5382/60000 (9%)
#
# Epoch:  74
# Loss=  tensor(2.0677)
#
# Test set, Epoch 75 , Average loss: 2.5118, Accuracy: 6363/60000 (11%)
#
# Epoch:  75
# Loss=  tensor(2.0636)
#
# Test set, Epoch 76 , Average loss: 2.5131, Accuracy: 6276/60000 (10%)
#
# Epoch:  76
# Loss=  tensor(2.0612)
#
# Test set, Epoch 77 , Average loss: 2.4703, Accuracy: 6932/60000 (12%)
#
# Epoch:  77
# Loss=  tensor(2.0565)
#
# Test set, Epoch 78 , Average loss: 2.5338, Accuracy: 5682/60000 (9%)
#
# Epoch:  78
# Loss=  tensor(2.0533)
#
# Test set, Epoch 79 , Average loss: 2.5482, Accuracy: 5620/60000 (9%)
#
# Epoch:  79
# Loss=  tensor(2.0496)
#
# Test set, Epoch 80 , Average loss: 2.5539, Accuracy: 5639/60000 (9%)
#
# Epoch:  80
# Loss=  tensor(2.0461)
#
# Test set, Epoch 81 , Average loss: 2.5583, Accuracy: 6357/60000 (11%)
#
# Epoch:  81
# Loss=  tensor(2.0430)
#
# Test set, Epoch 82 , Average loss: 2.5495, Accuracy: 5777/60000 (10%)
#
# Epoch:  82
# Loss=  tensor(2.0394)
#
# Test set, Epoch 83 , Average loss: 2.5423, Accuracy: 6130/60000 (10%)
#
# Epoch:  83
# Loss=  tensor(2.0349)
#
# Test set, Epoch 84 , Average loss: 2.5462, Accuracy: 6020/60000 (10%)
#
# Epoch:  84
# Loss=  tensor(2.0321)
#
# Test set, Epoch 85 , Average loss: 2.5070, Accuracy: 6839/60000 (11%)
#
# Epoch:  85
# Loss=  tensor(2.0283)
#
# Test set, Epoch 86 , Average loss: 2.5898, Accuracy: 5638/60000 (9%)
#
# Epoch:  86
# Loss=  tensor(2.0258)
#
# Test set, Epoch 87 , Average loss: 2.5371, Accuracy: 6078/60000 (10%)
#
# Epoch:  87
# Loss=  tensor(2.0226)
#
# Test set, Epoch 88 , Average loss: 2.5861, Accuracy: 5783/60000 (10%)
#
# Epoch:  88
# Loss=  tensor(2.0179)
#
# Test set, Epoch 89 , Average loss: 2.5853, Accuracy: 5977/60000 (10%)
#
# Epoch:  89
# Loss=  tensor(2.0144)
#
# Test set, Epoch 90 , Average loss: 2.6147, Accuracy: 5468/60000 (9%)
#
# Epoch:  90
# Loss=  tensor(2.0127)
#
# Test set, Epoch 91 , Average loss: 2.6432, Accuracy: 5213/60000 (9%)
#
# Epoch:  91
# Loss=  tensor(2.0079)
#
# Test set, Epoch 92 , Average loss: 2.5987, Accuracy: 5415/60000 (9%)
#
# Epoch:  92
# Loss=  tensor(2.0050)
#
# Test set, Epoch 93 , Average loss: 2.5843, Accuracy: 6386/60000 (11%)
#
# Epoch:  93
# Loss=  tensor(2.0016)
#
# Test set, Epoch 94 , Average loss: 2.5705, Accuracy: 6139/60000 (10%)
#
# Epoch:  94
# Loss=  tensor(1.9974)
#
# Test set, Epoch 95 , Average loss: 2.6265, Accuracy: 5429/60000 (9%)
#
# Epoch:  95
# Loss=  tensor(1.9955)
#
# Test set, Epoch 96 , Average loss: 2.6072, Accuracy: 6033/60000 (10%)
#
# Epoch:  96
# Loss=  tensor(1.9920)
#
# Test set, Epoch 97 , Average loss: 2.6500, Accuracy: 5421/60000 (9%)
#
# Epoch:  97
# Loss=  tensor(1.9887)
#
# Test set, Epoch 98 , Average loss: 2.5841, Accuracy: 6126/60000 (10%)
#
# Epoch:  98
# Loss=  tensor(1.9854)
#
# Test set, Epoch 99 , Average loss: 2.5838, Accuracy: 6473/60000 (11%)
#
# Epoch:  99
# Loss=  tensor(1.9817)
#
# Test set, Epoch 100 , Average loss: 2.6233, Accuracy: 5862/60000 (10%)
#
# Epoch:  100
# Loss=  tensor(1.9797)

# %%
temp_1 = []
for i in m1_train_loss_arr:
    temp_1.append(i.data.numpy().tolist())
temp_2 = []
for i in m1_test_loss_arr:
    temp_2.append(i.data.numpy().tolist())

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(0, 100, 1), temp_1, color = "r")
plt.plot(np.arange(0, 100, 1), temp_2, color = "g")
plt.title('Model Loss Comparision')
plt.legend(['Train Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
